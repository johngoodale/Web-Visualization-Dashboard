# %%
# Dependencies
import pandas as pd

# %%
# File path
city_weather = "Resources/city_weather_df.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
city_weather_df = pd.read_csv(city_weather, encoding="ISO-8859-1")
city_weather_df.head()
# Out:
#    City_ID             City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0    Leningradskiy           5      RU  1562800668        68  69.38
# 1        1          Kendari          97      ID  1562800669        88  -3.99
# 2        2  Arraial do Cabo           0      BR  1562800670        77 -22.97
# 3        3        Alyangula          30      AU  1562800671       100 -13.85
# 4        4   Lakes Entrance          62      AU  1562800673        56 -37.88
#
#       Lng  Max Temp  Wind Speed
# 0  178.42     43.91        5.99
# 1  122.52     74.15        2.37
# 2  -42.02     66.20        8.05
# 3  136.42     66.20        8.05
# 4  147.99     53.01        4.00

# %%
city_weather_html = city_weather_df.to_html()
city_weather_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City_ID</th>\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Humidity</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>Leningradskiy</td>\n      <td>5</td>\n      <td>RU</td>\n      <td>1562800668</td>\n      <td>68</td>\n      <td>69.38</td>\n      <td>178.42</td>\n      <td>43.91</td>\n      <td>5.99</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Kendari</td>\n      <td>97</td>\n      <td>ID</td>\n      <td>1562800669</td>\n      <td>88</td>\n      <td>-3.99</td>\n      <td>122.52</td>\n      <td>74.15</td>\n      <td>2.37</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>Arraial do Cabo</td>\n      <td>0</td>\n      <td>BR</td>\n
# ...

# %%
city_weather_df.to_html('city_weather_html')
